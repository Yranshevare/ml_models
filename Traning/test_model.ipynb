# %%
import pickle

# Load model
model = pickle.load(open("pkl/car_price_model_final.pkl", "rb"))

# %%
# print(model.named_steps['grib_pipeline'])

# print(model.named_steps)
best_params = model.named_steps["gridsearchcv"].best_params_
print(best_params)
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 100, 'n_estimators': 400}

# %%
sample = {
    "year": 2007,
    "km_driven": 70000,
    "fuel": "Petrol",
    "seller_type": "Individual",
    "transmission": "Manual",
    "owner": "Second Owner"
}

encoded_cats = encoder.transform([[
    sample["fuel"],
    sample["seller_type"],
    sample["transmission"],
    sample["owner"]
]])

final_input = [[
    sample["year"],
    sample["km_driven"],
    encoded_cats[0][0],  # fuel
    encoded_cats[0][1],  # seller
    encoded_cats[0][2],  # transmission
    encoded_cats[0][3]   # owner
]]

final_input
# Out:
# C:\Users\Yadnesh\OneDrive\Desktop\codes\ml_model\Traning\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# [[2007,
#   70000,
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(1.0)]]

# %%
prediction = model.predict(final_input)
print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: 136582.36342352096
# C:\Users\Yadnesh\OneDrive\Desktop\codes\ml_model\Traning\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## testing improves one

# %%
import pickle

pipe = pickle.load(open("pkl/car_price_model_improved.pkl", "rb"))

# %%
import pandas as pd

sample = {
    "year": 2012,
    "km_driven": 100000,
    "fuel": "Diesel",
    "company": "Hyundai"
}

sample_df = pd.DataFrame([sample])

# %%
pipe.predict(sample_df)
# Out:
# array([474481.36277252])
